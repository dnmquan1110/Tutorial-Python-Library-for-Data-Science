# %%
from matplotlib import pylab
pylab.__version__
# Out:
# '1.21.5'

# %%
import numpy as np
x = np.linspace(0,10,25)
y = x*x+2
np.array([x,y]).reshape(25,2)
# Out:
# array([[  0.        ,   0.41666667],
#        [  0.83333333,   1.25      ],
#        [  1.66666667,   2.08333333],
#        [  2.5       ,   2.91666667],
#        [  3.33333333,   3.75      ],
#        [  4.16666667,   4.58333333],
#        [  5.        ,   5.41666667],
#        [  5.83333333,   6.25      ],
#        [  6.66666667,   7.08333333],
#        [  7.5       ,   7.91666667],
#        [  8.33333333,   8.75      ],
#        [  9.16666667,   9.58333333],
#        [ 10.        ,   2.        ],
#        [  2.17361111,   2.69444444],
#        [  3.5625    ,   4.77777778],
#        [  6.34027778,   8.25      ],
#        [ 10.50694444,  13.11111111],
#        [ 16.0625    ,  19.36111111],
#        [ 23.00694444,  27.        ],
#        [ 31.34027778,  36.02777778],
#        [ 41.0625    ,  46.44444444],
#        [ 52.17361111,  58.25      ],
#        [ 64.67361111,  71.44444444],
#        [ 78.5625    ,  86.02777778],
#        [ 93.84027778, 102.        ]])

# %%
pylab.plot(x,y,'g')

# %%
pylab.subplot(1,2,1)
pylab.plot(x,y,'r--')
pylab.subplot(1,2,2)
pylab.plot(y,x,'g+-')

# %%
pylab.subplot(1,2,1)
pylab.plot(x,y,'r--')
pylab.subplot(2,2,2)
pylab.plot(y,x,'g+-')

# %%
pylab.subplot(1,2,1)
pylab.plot(x,y,'r--')
pylab.subplot(2,2,2)
pylab.plot(y,x,'g+-')
pylab.subplot(2,3,3)
pylab.plot(y,x,'g+-')

# %%
pylab.subplot(1,2,1)
pylab.plot(x,y,'r--')
pylab.subplot(1,2,1)
pylab.plot(y,x,'g+-')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
axis = fig.add_axes([0.5,0.1,0.8,0.8])
axis.plot(x,y,'r')

# %%
fig, axes = plt.subplots(nrows=1,ncols=2)
for ax in axes:
    ax.plot(x,y,'r')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.3,0.3])

axes1.plot(x,y,'r')
axes2.plot(y,x,'g')

# %%
fig = plt.figure(figsize=(16,9),dpi=100)
fig.add_subplot()

plt.plot(x,y,'r')

# %%
fig, axes = plt.subplots()
axes.set_title('title')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.plot(x,x**2)
axes.plot(x,x**3)
axes.legend(['x**2','x**3'])

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x,x+1,color='r')
axes.plot(x,x+2)
axes.plot(x,x+3)

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x,x**2,color='r',alpha=.3)
axes.plot(x,x+2,color='g',alpha=.5)
axes.plot(x,x+3,color='b',alpha=.8)

# %%
fig,ax=plt.subplots(dpi=100)

ax.plot(x,x+1,color='b',lw=1, linestyle='-')
ax.plot(x,x+2,color='b',linewidth=1.5, linestyle=':')
ax.plot(x,x+3,color='b',linewidth=2, linestyle='-.')

line, = ax.plot(x,x+4,color='black',lw=1.5)
line.set_dashes([5,10,15,10])
line, = ax.plot(x,x+5,color='black',lw=1.5)
line.set_dashes([5,10,15,20])

# %%
fig,ax=plt.subplots(dpi=100)

ax.plot(x,x+1,color='b',marker='o')
ax.plot(x,x+2,color='b',marker='+')
ax.plot(x,x+3,color='b',marker='s')
ax.plot(x,x+4,color='b',marker='1')
ax.plot(x,x+5,color='b',marker='o',markersize=10)
ax.plot(x,x+6,color='b',marker='s',markerfacecolor='r')
ax.plot(x,x+7,color='b',marker='s',markerfacecolor='g',markersize=5)

# %%
fig, axes = plt.subplots(1,2,figsize=(10,5))
axes[0].plot(x,x**2,x**3,lw=2)
axes[0].grid(True)

axes[1].plot(x,x**2,x**3,lw=2)
axes[1].set_ylim([0,60])
axes[1].set_xlim([2,5])
# Out:
# (2.0, 5.0)

# %%
n = np.arange(6)

fig,axes = plt.subplots(1,4,figsize=(16,5))
axes[0].set_title('scatter')
axes[0].scatter(x,x+0.25*np.random.rand(len(x)))

axes[1].set_title('step')
axes[1].step(n,n**2,lw=2)

axes[2].set_title('bar')
axes[2].bar(n,n**2,align='center',width=.5,alpha=.5)

axes[3].set_title('fill between')
axes[3].fill_between(x,x**2,x**3,color='g',alpha=.5)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0,0,1,1],polar=1)
t = np.linspace(0,2*np.pi,100)
ax.plot(t,t*3,color='b',lw=3)

# %%
n = np.random.randn(100000)
fig,axes = plt.subplots(1,2,figsize=(12,4))

axes[0].set_title('Default histogram')
axes[0].hist(n)

axes[1].set_title('Cumulative detailed histogram')
axes[1].hist(n,cumulative=1,bins=10)
# Out:
# (array([5.9000e+01, 1.0910e+03, 7.8950e+03, 3.0040e+04, 6.4053e+04,
#         8.9429e+04, 9.8329e+04, 9.9871e+04, 9.9992e+04, 1.0000e+05]),
#  array([-4.06718946, -3.18059838, -2.29400729, -1.40741621, -0.52082512,
#          0.36576596,  1.25235704,  2.13894813,  3.02553921,  3.9121303 ,
#          4.79872138]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.cm as cm
import matplotlib

delta = .025
x = np.arange(-3,3,delta)
y = np.arange(-2,2,delta)
X,Y = np.meshgrid(x,y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X-1)**2-(Y-1)**2)
Z = (Z1-Z2)*2

# %%
fig,ax = plt.subplots()
CS = ax.contour(X,Y,Z)
ax.clabel(CS,inline=1,fontsize=10)
ax.set_title('contour map')
# Out:
# Text(0.5, 1.0, 'contour map')

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))

ax = fig.add_subplot(1,2,1,projection='3d')
ax.plot_surface(X,Y,Z,rstride=4,cstride=4,lw=0)

# %%
languages = 'Python','Java','PHP','Javascript','C#','C++'
popularity = [22.2,17.6,8.8,8,7.7,6.7]
colors = ['#1f77b4','#ff7f0e','#2ca02c','#d62728','#9467bd','#8c564b']

# %%
explode = (0.1,0,0,0,0,0)

plt.pie(popularity, explode=explode, labels=languages,colors=colors,
autopct='%1.1f%%',shadow=1, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x1cdccdef190>,
# ...
#  [Text(-1.1518739051683529, -0.33643202373170245, 'Python'),
#   Text(0.5025192070582963, -0.978506232242545, 'Java'),
#   Text(1.0971674240514186, 0.07889007288863878, 'PHP'),
#   Text(0.754341041824552, 0.8006057660415953, 'Javascript'),
#   Text(0.06701830757132049, 1.0979565321315212, 'C#'),
#   Text(-0.5993297985645449, 0.9223902604389219, 'C++')],
#  [Text(-0.6719264446815391, -0.19625201384349306, '31.3%'),
#   Text(0.2741013856681616, -0.5337306721322972, '24.8%'),
#   Text(0.5984549585735011, 0.043030948848348426, '12.4%'),
#   Text(0.41145875008611926, 0.4366940542045065, '11.3%'),
#   Text(0.036555440493447534, 0.5988853811626479, '10.8%'),
#   Text(-0.3269071628533881, 0.5031219602394119, '9.4%')])
